# %% [markdown]
# # Starter Notebook

# %% [markdown]
# In order to help minimize start up difficulties, we have provided you with a basic ML workflow for this project, as well as a few possible avenues to explore.

# %% [markdown]
# ## Section 1: ML Workflow for Submitting *(g,h)* pairs

# %% [markdown]
# ### 1.0 Pip Installs and Imports
#
# We will be using a package *dill* which is a variant of *pickle*, but allows a bit more expressive byte code serialization. This package is essential to saving your *(g,h)* pairs!.

# %%
# !pip install dill
# Out:
# Requirement already satisfied: dill in /Users/rohan/opt/anaconda3/envs/cis423/lib/python3.10/site-packages (0.3.6)

# %% [markdown]
# Here is a non-inclusive list of packages you may find helpful

# %%
# Imports

import numpy as np
import pandas as pd
import sklearn as sk
from sklearn import *
import dill as pkl
import math
import time
from sklearn.metrics import mean_squared_error
import random
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from googleapiclient.http import MediaFileUpload
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2 import service_account
from github import Github
import string
import os

# %% [markdown]
# ### 1.1 Download/Load Data
#
# Navigate to the project [webpage](https://declancharrison.github.io/CIS_5230_Bias_Bounty_2023/) and click "Download Training Data". Extract the .zip files in the folder where this notebook is located, then run the cell below.

# %%
x_train = pd.read_csv('training_data.csv') 
y_train = np.genfromtxt('training_labels.csv', delimiter=',', dtype = float)
prediction_path = 'training_predictions.csv'
x_predictions = np.loadtxt(prediction_path, delimiter=",", dtype=str).astype('float64')
print(f'x_predictions.shape: {x_predictions.shape}')
# Out:
# x_predictions.shape: (340134,)

# %% [markdown]
# ### 1.2 Define a (g,h) pair
#
# Below is an example of training a Decision Tree Regressor on individuals identified as white from the dataset.

# %%
def submit_to_drive(file_name):
    creds = None
    SCOPES = 'https://www.googleapis.com/auth/drive'
    creds = service_account.Credentials.from_service_account_file(
    './s_key.json',
    scopes=['https://www.googleapis.com/auth/drive']
    )       
    # Save the credentials for the next run

    #creds = Credentials.from_authorized_user_file('./key.json', ['https://www.googleapis.com/auth/drive'])
    service = build('drive', 'v3', credentials=creds)
    # Set up the file metadata
    # find the "cis" folder
    folder_name = "423 3"
    query = "mimeType='application/vnd.google-apps.folder' and trashed=false and name='%s'" % folder_name
    folder = service.files().list(q=query).execute().get('files', [])[0]

    # find the file you want to overwrite
    query = "mimeType='application/octet-stream' and trashed=false and name='%s' and parents in '%s'" % (file_name, folder['id'])
    file = service.files().list(q=query).execute().get('files', [])[0]

    # upload the updated file
    file_metadata = {'name': file_name}
    media = MediaFileUpload(f'./{file_name}', mimetype='application/octet-stream')
    file = service.files().update(fileId=file['id'], body=file_metadata, media_body=media, fields='id').execute()

    print("File overwritten successfully.")

# %%
submit_to_drive('g_2.pkl')
# Out:
# File overwritten successfully.

# %%
def github_request(name):
    g = Github('insert github key')
    repo = g.get_repo("Declancharrison/CIS_5230_Bias_Bounty_2023")
    branch = repo.get_branch("main")
    new_branch = repo.create_git_ref(f"refs/heads/{name}", branch.commit.sha)
    file = repo.get_contents("competitors/request.yaml", ref=name)
    g_drive = "https://drive.google.com/file/d/1pq--9QJIaTFtsMsVH76iRbtxpgB--Tjs/view?usp=share_link"
    h_drive = "https://drive.google.com/file/d/1BQ8u2JD9DMTPtESEABHkcJHkQKbx0GBf/view?usp=share_link"

    file_content = f"# insert URL links to each model\n\n# google drive group function\n\ng_url : \"{g_drive}\"\n\n# google drive hypothesis function\n\nh_url : \"{h_drive}\"\n\n### DO NOT DELETE NEWLINE"

    repo.update_file(
        file.path,
        "commit message",
        file_content,
        file.sha,
        branch=name
    )
    while (True):
        try:
            pull = repo.create_pull(
            title="auto",
            body="auto",
            head=name,
            base=branch.name
            )
            break
            
        except Exception as e:
            print(e)
            time.sleep(600)
    print(f"Created pull request #{pull.number}: {pull.title}")
    return pull

# %%
def generate_random_string(length):
    letters = string.ascii_lowercase
    result_str = ''.join(random.choice(letters) for i in range(length))
    return result_str
generate_random_string(10)
# Out:
# 'seawtzztij'

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# Load the US Census data into a Pandas DataFrame
df = pd.read_csv('training_data.csv')

# Define the list of column codes
columns = ['COW', 'DDRS', 'DEAR', 'DEYE', 'DOUT', 'DRAT', 'DREM', 'ENG', 'FER', 'JWTRNS', 'MAR', 'MIL', 'SCHL', 'SEX', 'RAC1P', 'CIT', 'AGEP', 'WKHP', 'OCCP']

# Define an empty dictionary to store the results
result = {}

# Loop through each column in the list of column codes
for column in columns:
    
    # Check if the column is categorical or continuous
    if column in [ 'CIT', 'COW', 'DDRS', 'DEAR', 'DEYE', 'DOUT', 'DRAT', 'DREM', 'ENG', 'FER', 'JWTRNS', 'MAR', 'MIL', 'SCHL', 'SEX', 'RAC1P']:
            
        # For categorical columns, get the unique values and add them as values in the dictionary
        result[column] = df[column].unique().tolist()
        
    elif column == 'AGEP':
        
        # For the continuous variable, create 5 equally sized bins or 'quadrants' and add them as values in the dictionary
        result[column] = [17, 32.4, 47.8, 63.2, 78.6, 94.0]

    elif column == 'WKHP':
        
        # For another continuous variable, create 5 equally sized bins or 'quadrants' and add them as values in the dictionary
        result[column] = [1, 20.6, 40.2, 59.8, 79.4, 99.0]
    elif column == 'OCCP':
        
        # For another continuous variable, create 5 equally sized bins or 'quadrants' and add them as values in the dictionary
        result[column] = [0, 2000, 4000, 6000, 8000, 10000]
        
# Print the resulting dictionary
print(result)
# Out:
# {'COW': [1.0, 6.0, 4.0, 2.0, 7.0, 3.0, 5.0, 8.0], 'DDRS': [2.0, 1.0], 'DEAR': [2.0, 1.0], 'DEYE': [2.0, 1.0], 'DOUT': [2.0, 1.0], 'DRAT': [0.0, 6.0, 3.0, 2.0, 4.0, 5.0, 1.0], 'DREM': [2.0, 1.0], 'ENG': [0.0, 4.0, 1.0, 3.0, 2.0], 'FER': [2.0, 0.0, 1.0], 'JWTRNS': [0.0, 1.0, 11.0, 12.0, 8.0, 10.0, 3.0, 2.0, 9.0, 7.0, 6.0, 5.0, 4.0], 'MAR': [5.0, 2.0, 3.0, 4.0, 1.0], 'MIL': [4.0, 1.0, 2.0, 3.0], 'SCHL': [16.0, 19.0, 1.0, 22.0, 15.0, 5.0, 20.0, 14.0, 18.0, 21.0, 17.0, 13.0, 7.0, 23.0, 24.0, 10.0, 11.0, 12.0, 9.0, 6.0, 8.0, 4.0, 2.0, 3.0], 'SEX': [2.0, 1.0], 'RAC1P': [2.0, 1.0, 3.0, 6.0, 8.0, 9.0, 7.0, 4.0, 5.0], 'CIT': [1.0, 5.0, 4.0, 2.0, 3.0], 'AGEP': [17, 32.4, 47.8, 63.2, 78.6, 94.0], 'WKHP': [1, 20.6, 40.2, 59.8, 79.4, 99.0], 'OCCP': [0, 2000, 4000, 6000, 8000, 10000]}

# %%
### This is the Automation Code to test the non-categorical variables AGEP, WKHP, OCCP with every possible combination of the other variables
### We run 2 more separate notebooks in parallel (with different g_drive links, folders) to test other combinations
def write_pkl(g, h):
    with open(f'g_2.pkl', 'wb') as file:
        pkl.dump(g, file)

    with open('h_2.pkl', 'wb') as file:
        pkl.dump(h, file)
pull = "init"
models = [sk.ensemble.RandomForestRegressor, sk.ensemble.GradientBoostingRegressor]
params = [[(75, 100, 125, 150), (5, 10, 15)], [(75, 100, 125, 150), (5, 10, 15), (2, 5, 10)]]
result_keys = list(result.keys())
continous_vars = ['AGEP', 'WKHP', 'OCCP']
for ii in range(len(continous_vars)):
    for jj in range(len(result_keys)):
        key1 = continous_vars[ii]
        key2 = result_keys[jj]
        if (key2 == 'AGEP' or key2 == 'WKHP' or key2 == 'OCCP'):
            continue
        for val1 in range(len(result[key1]) - 1):
            for val2 in range(len(result[key2])):
                best_model = -1
                best_param = -1
                best_rmse = 1000000000
                indices = ((x_train[key1] >= result[key1][val1]) & (x_train[key1] < result[key1][val1 + 1]) & 
                                      (x_train[key2] == result[key2][val2]))
                if len(x_train[indices]) <= 5:
                    continue
                x_train_subset, x_val, y_train_subset, y_val = sk.model_selection.train_test_split(x_train[indices], y_train[indices], test_size = .15, random_state = 42)

                
                def get_g(X, k1 = key1, k2 = key2, v1 = result[key1][val1], v11 = result[key1][val1 + 1], v2 = result[key2][val2]):
                    return ((X[k1] >= v1) & (X[k1] < v11) & (X[k2] == v2))
                
                print(f"{key1}: {result[key1][val1]} {result[key1][val1 + 1]} -- {key2}: {result[key2][val2]}")
                try:
                    x_train_subset, x_val, y_train_subset, y_val = sk.model_selection.train_test_split(x_train[indices], y_train[indices], test_size = .15, random_state = 42)
                except:
                    continue
                if (len(x_train_subset) <=3):
                    continue
                print(len(x_train_subset))
                for i in range(len(models) - 1):
                    if (i == 0):
                        j = params[0]
                        for k in range(len(j[0])):
                            for kk in range(len(j[1])):
                                clf = models[i](n_estimators = j[0][k], max_depth = j[1][kk])
                                clf.fit(x_train_subset, y_train_subset)
                                mse = mean_squared_error(clf.predict(x_val), y_val)
                                rmse = math.sqrt(mse)
                                if (rmse < best_rmse):
                                    best_rmse = rmse
                                    best_model = 0
                                    best_param = (j[0][k], j[1][kk])

                        
                    if (i == 1):
                        j = params[1]
                        for k in range(len(j[0])): 
                            for kk in range(len(j[1])):
                                for kkk in range(len(j[2])):
                                    clf = models[i](n_estimators = j[0][k], max_depth = j[1][kk], min_samples_split = j[2][kkk])
                                    clf.fit(x_train_subset, y_train_subset)
                                    mse = mean_squared_error(clf.predict(x_val), y_val)
                                    rmse = math.sqrt(mse)
                                    #print(f"GB: {j[0][k] , j[1][kk], j[2][kkk]}: {rmse}")
                                    if (rmse < best_rmse):
                                        best_rmse = rmse
                                        best_model = 1
                                        best_param = (j[0][k], j[1][kk], j[2][kkk])
                                    
            
                    
                if best_model == 0: 
                    def get_h(x_train_h, y_train_h, n_estim = best_param[0], max_d = best_param[1]):
                        clf = sk.ensemble.RandomForestRegressor(n_estimators = n_estim, max_depth = max_d)
                        # find group indices on data
                        indices_h = get_g(x_train_h)

                        # fit model specifically to group
                        clf.fit(x_train_h[indices_h], y_train_h[indices_h])

                        # define hypothesis function as bound clf.predict
                        h = clf.predict

                        return h
                    h = get_h(x_train, y_train)
                    write_pkl(get_g, h)
                

        
                if best_model == 1:
                    def get_h(x_train_h, y_train_h, n_estim = best_param[0], max_d = best_param[1], min_s_s = best_param[2]):
                        clf = sk.ensemble.GradientBoostingRegressor(n_estimators = n_estim, max_depth = max_d, min_samples_split = min_s_s)
                        # find group indices on data
                        indices_h = get_g(x_train_h)

                        # fit model specifically to group
                        clf.fit(x_train_h[indices_h], y_train_h[indices_h])

                        # define hypothesis function as bound clf.predict
                        h = clf.predict
                        return h
                    h = get_h(x_train, y_train)
                    write_pkl(get_g, h)
                
                if pull != "init":
                    print("waiting")
                    while pull is not None and pull.state == "open":
                        try:
                            pull.update()  
                        except:
                            ()
                
                submit_to_drive('g_2.pkl')
                submit_to_drive('h_2.pkl')
                pull = github_request(f'f1eAWO-{generate_random_string(10)}')
# Out:
# WKHP: 1 20.6 -- MAR: 5.0
# 17568
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7569: auto
# WKHP: 1 20.6 -- MAR: 2.0
# 1487
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7571: auto
# WKHP: 1 20.6 -- MAR: 3.0
# 3423
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7573: auto
# WKHP: 1 20.6 -- MAR: 4.0
# 544
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7576: auto
# WKHP: 1 20.6 -- MAR: 1.0
# 15474
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7578: auto
# WKHP: 20.6 40.2 -- MAR: 5.0
# 65636
# waiting
# File overwritten successfully.
# File overwritten successfully.
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# Created pull request #7587: auto
# WKHP: 20.6 40.2 -- MAR: 2.0
# 4451
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7590: auto
# WKHP: 20.6 40.2 -- MAR: 3.0
# 22314
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7593: auto
# WKHP: 20.6 40.2 -- MAR: 4.0
# 4090
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7596: auto
# WKHP: 20.6 40.2 -- MAR: 1.0
# 94933
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7604: auto
# WKHP: 40.2 59.8 -- MAR: 5.0
# 11991
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7607: auto
# WKHP: 40.2 59.8 -- MAR: 2.0
# 733
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7609: auto
# WKHP: 40.2 59.8 -- MAR: 3.0
# 5292
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7611: auto
# WKHP: 40.2 59.8 -- MAR: 4.0
# 838
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7613: auto
# WKHP: 40.2 59.8 -- MAR: 1.0
# 25137
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7616: auto
# WKHP: 59.8 79.4 -- MAR: 5.0
# 3176
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7618: auto
# WKHP: 59.8 79.4 -- MAR: 2.0
# 190
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7620: auto
# WKHP: 59.8 79.4 -- MAR: 3.0
# 1518
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7622: auto
# WKHP: 59.8 79.4 -- MAR: 4.0
# 301
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7624: auto
# WKHP: 59.8 79.4 -- MAR: 1.0
# 7394
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7626: auto
# WKHP: 79.4 99.0 -- MAR: 5.0
# 625
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7628: auto
# WKHP: 79.4 99.0 -- MAR: 2.0
# 38
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7630: auto
# WKHP: 79.4 99.0 -- MAR: 3.0
# 284
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7632: auto
# WKHP: 79.4 99.0 -- MAR: 4.0
# 52
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7634: auto
# WKHP: 79.4 99.0 -- MAR: 1.0
# 1240
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7636: auto
# WKHP: 1 20.6 -- MIL: 4.0
# 36242
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7641: auto
# WKHP: 1 20.6 -- MIL: 1.0
# 98
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7644: auto
# WKHP: 1 20.6 -- MIL: 2.0
# 1750
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7647: auto
# WKHP: 1 20.6 -- MIL: 3.0
# 408
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7649: auto
# WKHP: 20.6 40.2 -- MIL: 4.0
# 178132
# waiting
# File overwritten successfully.
# File overwritten successfully.
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# Created pull request #7668: auto
# WKHP: 20.6 40.2 -- MIL: 1.0
# 1977
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7670: auto
# WKHP: 20.6 40.2 -- MIL: 2.0
# 9390
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7672: auto
# WKHP: 20.6 40.2 -- MIL: 3.0
# 1924
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7674: auto
# WKHP: 40.2 59.8 -- MIL: 4.0
# 39833
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7679: auto
# WKHP: 40.2 59.8 -- MIL: 1.0
# 960
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7681: auto
# WKHP: 40.2 59.8 -- MIL: 2.0
# 2714
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7683: auto
# WKHP: 40.2 59.8 -- MIL: 3.0
# 486
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7685: auto
# WKHP: 59.8 79.4 -- MIL: 4.0
# 10958
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7687: auto
# WKHP: 59.8 79.4 -- MIL: 1.0
# 548
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7689: auto
# WKHP: 59.8 79.4 -- MIL: 2.0
# 888
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7691: auto
# WKHP: 59.8 79.4 -- MIL: 3.0
# 186
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7693: auto
# WKHP: 79.4 99.0 -- MIL: 4.0
# 1920
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7695: auto
# WKHP: 79.4 99.0 -- MIL: 1.0
# 82
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7697: auto
# WKHP: 79.4 99.0 -- MIL: 2.0
# 192
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7699: auto
# WKHP: 79.4 99.0 -- MIL: 3.0
# 45
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7702: auto
# WKHP: 1 20.6 -- SCHL: 16.0
# 7960
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7705: auto
# WKHP: 1 20.6 -- SCHL: 19.0
# 7114
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7707: auto
# WKHP: 1 20.6 -- SCHL: 1.0
# 490
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7709: auto
# WKHP: 1 20.6 -- SCHL: 22.0
# 2856
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7711: auto
# WKHP: 1 20.6 -- SCHL: 15.0
# 924
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7713: auto
# WKHP: 1 20.6 -- SCHL: 5.0
# 9
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7715: auto
# WKHP: 1 20.6 -- SCHL: 20.0
# 2885
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7717: auto
# WKHP: 1 20.6 -- SCHL: 14.0
# 2373
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7719: auto
# WKHP: 1 20.6 -- SCHL: 18.0
# 3259
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7721: auto
# WKHP: 1 20.6 -- SCHL: 21.0
# 6652
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7723: auto
# WKHP: 1 20.6 -- SCHL: 17.0
# 1249
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7725: auto
# WKHP: 1 20.6 -- SCHL: 13.0
# 841
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7727: auto
# WKHP: 1 20.6 -- SCHL: 7.0
# 28
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7729: auto
# WKHP: 1 20.6 -- SCHL: 23.0
# 615
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7731: auto
# WKHP: 1 20.6 -- SCHL: 24.0
# 449
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7733: auto
# WKHP: 1 20.6 -- SCHL: 10.0
# 71
# waiting
# File overwritten successfully.
# File overwritten successfully.
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# Created pull request #7735: auto
# WKHP: 1 20.6 -- SCHL: 11.0
# 177
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7737: auto
# WKHP: 1 20.6 -- SCHL: 12.0
# 322
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7739: auto
# WKHP: 1 20.6 -- SCHL: 9.0
# 126
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7741: auto
# WKHP: 1 20.6 -- SCHL: 6.0
# 24
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7743: auto
# WKHP: 1 20.6 -- SCHL: 8.0
# 36
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7745: auto
# WKHP: 1 20.6 -- SCHL: 4.0
# 6
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7746: auto
# WKHP: 1 20.6 -- SCHL: 2.0
# 15
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7748: auto
# WKHP: 1 20.6 -- SCHL: 3.0
# 5
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7750: auto
# WKHP: 20.6 40.2 -- SCHL: 16.0
# 46332
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7751: auto
# WKHP: 20.6 40.2 -- SCHL: 19.0
# 28781
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7752: auto
# WKHP: 20.6 40.2 -- SCHL: 1.0
# 2738
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7753: auto
# WKHP: 20.6 40.2 -- SCHL: 22.0
# 14685
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7754: auto
# WKHP: 20.6 40.2 -- SCHL: 15.0
# 3459
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7755: auto
# WKHP: 20.6 40.2 -- SCHL: 5.0
# 97
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7756: auto
# WKHP: 20.6 40.2 -- SCHL: 20.0
# 18896
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7757: auto
# WKHP: 20.6 40.2 -- SCHL: 14.0
# 3530
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7758: auto
# WKHP: 20.6 40.2 -- SCHL: 18.0
# 14324
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7759: auto
# WKHP: 20.6 40.2 -- SCHL: 21.0
# 38481
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7760: auto
# WKHP: 20.6 40.2 -- SCHL: 17.0
# 8132
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7761: auto
# WKHP: 20.6 40.2 -- SCHL: 13.0
# 2356
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7762: auto
# WKHP: 20.6 40.2 -- SCHL: 7.0
# 165
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7763: auto
# WKHP: 20.6 40.2 -- SCHL: 23.0
# 2256
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7764: auto
# WKHP: 20.6 40.2 -- SCHL: 24.0
# 1978
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7765: auto
# WKHP: 20.6 40.2 -- SCHL: 10.0
# 345
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7767: auto
# WKHP: 20.6 40.2 -- SCHL: 11.0
# 1007
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7769: auto
# WKHP: 20.6 40.2 -- SCHL: 12.0
# 1977
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7772: auto
# WKHP: 20.6 40.2 -- SCHL: 9.0
# 1161
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7775: auto
# WKHP: 20.6 40.2 -- SCHL: 6.0
# 258
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7777: auto
# WKHP: 20.6 40.2 -- SCHL: 8.0
# 320
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7779: auto
# WKHP: 20.6 40.2 -- SCHL: 4.0
# 62
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7781: auto
# WKHP: 20.6 40.2 -- SCHL: 2.0
# 36
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7783: auto
# WKHP: 20.6 40.2 -- SCHL: 3.0
# 37
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7785: auto
# WKHP: 40.2 59.8 -- SCHL: 16.0
# 9412
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7786: auto
# WKHP: 40.2 59.8 -- SCHL: 19.0
# 6398
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7787: auto
# WKHP: 40.2 59.8 -- SCHL: 1.0
# 592
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7788: auto
# WKHP: 40.2 59.8 -- SCHL: 22.0
# 4080
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7789: auto
# WKHP: 40.2 59.8 -- SCHL: 15.0
# 702
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7790: auto
# WKHP: 40.2 59.8 -- SCHL: 5.0
# 19
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7791: auto
# WKHP: 40.2 59.8 -- SCHL: 20.0
# 4117
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7792: auto
# WKHP: 40.2 59.8 -- SCHL: 14.0
# 555
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7793: auto
# WKHP: 40.2 59.8 -- SCHL: 18.0
# 3252
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7794: auto
# WKHP: 40.2 59.8 -- SCHL: 21.0
# 9995
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7795: auto
# WKHP: 40.2 59.8 -- SCHL: 17.0
# 1943
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7796: auto
# WKHP: 40.2 59.8 -- SCHL: 13.0
# 453
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7797: auto
# WKHP: 40.2 59.8 -- SCHL: 7.0
# 28
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7798: auto
# WKHP: 40.2 59.8 -- SCHL: 23.0
# 741
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7799: auto
# WKHP: 40.2 59.8 -- SCHL: 24.0
# 603
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7800: auto
# WKHP: 40.2 59.8 -- SCHL: 10.0
# 73
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7801: auto
# WKHP: 40.2 59.8 -- SCHL: 11.0
# 228
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7802: auto
# WKHP: 40.2 59.8 -- SCHL: 12.0
# 416
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7803: auto
# WKHP: 40.2 59.8 -- SCHL: 9.0
# 251
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7804: auto
# WKHP: 40.2 59.8 -- SCHL: 6.0
# 42
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7805: auto
# WKHP: 40.2 59.8 -- SCHL: 8.0
# 54
# waiting
# File overwritten successfully.
# File overwritten successfully.
# Created pull request #7807: auto
# WKHP: 40.2 59.8 -- SCHL: 4.0
# 14
# waiting
# File overwritten successfully.
# File overwritten successfully.
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# 403 {"message": "You have exceeded a secondary rate limit and have been temporarily blocked from content creation. Please retry your request again later.", "documentation_url": "https://docs.github.com/rest/overview/resources-in-the-rest-api#secondary-rate-limits"}
# 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
# 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
# 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
# 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
# 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
# 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
# 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
# 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
# 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# Cell In[6], line 21, in github_request(name)
#      20 try:
# ---> 21     pull = repo.create_pull(
#      22     title="auto",
#      23     body="auto",
#      24     head=name,
#      25     base=branch.name
#      26     )
#      27     break
#
# File ~/opt/anaconda3/envs/cis423/lib/python3.10/site-packages/github/Repository.py:1400, in Repository.create_pull(self, *args, **kwds)
#    1399 if len(args) + len(kwds) >= 4:
# -> 1400     return self.__create_pull_1(*args, **kwds)
#    1401 else:
#
# File ~/opt/anaconda3/envs/cis423/lib/python3.10/site-packages/github/Repository.py:1431, in Repository.__create_pull_1(self, title, body, base, head, maintainer_can_modify, draft)
#    1430 else:
# -> 1431     return self.__create_pull(
#    1432         title=title, body=body, base=base, head=head, draft=draft
#    1433     )
#
# File ~/opt/anaconda3/envs/cis423/lib/python3.10/site-packages/github/Repository.py:1444, in Repository.__create_pull(self, **kwds)
#    1442 post_parameters = kwds
# -> 1444 headers, data = self._requester.requestJsonAndCheck(
#    1445     "POST", f"{self.url}/pulls", input=post_parameters
#    1446 )
#    1447 return github.PullRequest.PullRequest(
#    1448     self._requester, headers, data, completed=True
#    1449 )
#
# File ~/opt/anaconda3/envs/cis423/lib/python3.10/site-packages/github/Requester.py:398, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     397 def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
# --> 398     return self.__check(
#     399         *self.requestJson(
#     400             verb, url, parameters, headers, input, self.__customConnection(url)
#     401         )
#     402     )
#
# File ~/opt/anaconda3/envs/cis423/lib/python3.10/site-packages/github/Requester.py:423, in Requester.__check(self, status, responseHeaders, output)
#     422 if status >= 400:
# --> 423     raise self.__createException(status, responseHeaders, output)
#     424 return responseHeaders, output
#
# GithubException: 422 {"message": "Validation Failed", "errors": [{"resource": "PullRequest", "field": "head", "code": "invalid"}], "documentation_url": "https://docs.github.com/rest/reference/pulls#create-a-pull-request"}
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 116
#     114 submit_to_drive('g_2.pkl')
#     115 submit_to_drive('h_2.pkl')
# --> 116 pull = github_request(f'f1eAWO-{generate_random_string(10)}')
#
# Cell In[6], line 31, in github_request(name)
#      29     except Exception as e:
#      30         print(e)
# ---> 31         time.sleep(600)
#      32 print(f"Created pull request #{pull.number}: {pull.title}")
#      33 return pull
#
# KeyboardInterrupt:
